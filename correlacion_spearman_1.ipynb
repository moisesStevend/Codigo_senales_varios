# %% [markdown]
# # Spearman correlation

# %% [markdown]
# Correlacion: Permite saber tanto la Magnitud como la direccion de la relación.

# %% [markdown]
# [![IMAGE_ALT](https://uncommunitymanager.es/wp-content/uploads/seo_google_youtube.jpg)](https://www.youtube.com/watch?v=lzF6NggCSdY&list=PLat2DtY8K7YUYdJf8O30vWwqa5nCPVclo&index=2)

# %% [markdown]
# ## What is a monotonic relationship?

# %% [markdown]
# A monotonic relationship is a relationship that does one of the following: (1) as the value of one variable increases, so does the value of the other variable; or (2) as the value of one variable increases, the other variable value decreases.

# %% [markdown]
# ![spearman_pearson.png](attachment:d1ddcdb6-bcb5-4313-8231-e3ce26d6366e.png)

# %% [markdown]
# ![spearman2.png](attachment:7c8cc08d-12d7-434c-9f60-377e7f86630c.png)

# %%
from scipy import stats
import matplotlib.pyplot as plt

# %%
goles = [2,15,3,8,0,11]
asistencias = [4,7,8,6,1,13]

stats.spearmanr(goles,asistencias)
# Out:
# SignificanceResult(statistic=0.7142857142857143, pvalue=0.1107871720116617)
